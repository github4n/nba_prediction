# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel('../数据清洗整理/features.xlsx')
df.columns
# Out:
# Index(['AST', 'BLK', 'BLKA', 'DREB', 'FG3A', 'FG3M', 'FGA', 'FGM', 'FTA',
#        'FTM', 'OREB', 'PF', 'PFD', 'PTS', 'PTS_2ND_CHANCE', 'PTS_FB',
#        'PTS_OFF_TOV', 'PTS_PAINT', 'REB', 'STL', 'TOV', 'MATCHUP', 'OPP_AST',
#        'OPP_BLK', 'OPP_BLKA', 'OPP_DREB', 'OPP_FG3A', 'OPP_FG3M', 'OPP_FGA',
#        'OPP_FGM', 'OPP_FTA', 'OPP_FTM', 'OPP_OREB', 'OPP_PF', 'OPP_PFD',
#        'OPP_PTS', 'OPP_PTS_2ND_CHANCE', 'OPP_PTS_FB', 'OPP_PTS_OFF_TOV',
#        'OPP_PTS_PAINT', 'OPP_REB', 'OPP_STL', 'OPP_TOV'],
#       dtype='object')

# %%
df[df['TOV']>20]
# Out:
#           AST  BLK  BLKA  DREB  FG3A  FG3M  FGA  FGM  FTA  FTM   ...     \
# 21600010   18    4     5    47    24     8   83   37   33   25   ...
# 21600014   28    7     4    38    26    12   88   44   18   14   ...
# 21600021   13    3     3    43    21     5   96   40   38   28   ...
# 21600029   21    5     6    37    28     8   84   38   26   15   ...
# 21600040   20    2     6    30    32     7   87   35   24   19   ...
# 21600045   19    0     4    34    15     5   84   35   31   23   ...
# 21600052   10    4     5    24    24     4   75   27   29   22   ...
# 21600052   29    5     4    40    20    12   78   43   23   18   ...
# 21600055   21    5     2    30    10     3   72   42   24   16   ...
# 21600060   17    9     5    38    34    11   81   30   16   12   ...
# 21600064   14    4     5    42    20     5   84   34   20   12   ...
# 21600066   29    4     6    22    23    10   81   38   27   21   ...
# 21600066   32    6     4    29    27    12   82   47   24   19   ...
# ...

# %%
df[df['TOV']<10]['MATCHUP']
# Out:
# 27      ATL @ POR
# 37    ATL vs. LAC
# 52      ATL @ DEN
# 62    ATL vs. DET
# Name: MATCHUP, dtype: object

# %%
df[df['PTS']>120]['MATCHUP']
# Out:
# 2     ATL vs. CLE
# 4     ATL vs. BOS
# 21    ATL vs. CLE
# 34    ATL vs. NYK
# 56      ATL @ TOR
# Name: MATCHUP, dtype: object

# %%
df[df['PTS']<90]['MATCHUP']
# Out:
# 0       ATL @ IND
# 5       ATL @ BKN
# 24      ATL @ ORL
# 26      ATL @ LAC
# 35    ATL vs. WAS
# 53    ATL vs. MIN
# 61      ATL @ TOR
# 62    ATL vs. DET
# 66      ATL @ UTA
# Name: MATCHUP, dtype: object
